# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

service = Service(ChromeDriverManager().install())
nav = webdriver.Chrome(service=service)
nav.get("https://web.whatsapp.com/")

# %%
i = 0
while i < 5:
    from selenium.webdriver.common.keys import Keys
    import pyperclip
    import time

    mensagem = """ 
    Para a honra e glória de Deus.
    """

    lista_contatos = ["SALVAR COISAS", "Meu Vivo"]

    #Enviar essa mensagem para o primeiro numero 

    #clicar na lupa
    nav.find_element('xpath', '//*[@id="side"]/div[1]/div/div/button/div[2]/span').click()
    time.sleep(1)
    #escrever SALVAR COISAS
    nav.find_element('xpath','//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').send_keys("Minha Princesa")
    #dar um enter
    nav.find_element('xpath','//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').send_keys(Keys.ENTER)

    time.sleep(1)

    #escrever a nossa mensagem 
    pyperclip.copy(mensagem)
    nav.find_element('xpath', '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys(Keys.CONTROL + "v")
    nav.find_element('xpath', '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]/p').send_keys(Keys.ENTER)

    #encaminhar a mensagem para a lista de contatos
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36656\2751591400.py in <module>
#      14
#      15     #clicar na lupa
# ---> 16     nav.find_element('xpath', '//*[@id="side"]/div[1]/div/div/button/div[2]/span').click()
#      17     time.sleep(1)
#      18     #escrever SALVAR COISAS
#
# c:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      91     def click(self) -> None:
#      92         """Clicks the element."""
# ---> 93         self._execute(Command.CLICK_ELEMENT)
#      94
#      95     def submit(self):
#
# c:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     392             params = {}
#     393         params["id"] = self._id
# --> 394         return self._parent.execute(command, params)
#     395
# ...
